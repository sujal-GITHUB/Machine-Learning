# %% [markdown]
# # Cost Function

# %% [markdown]
# PROBLEM:
# You would like a model which can predict housing prices given the size of the house.
# Let's use the same two data points as before the previous lab- a house with 1000 square feet sold for 300,000 dollars and a house with 2000 square feet sold for 500,000 dollars.

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x_train = np.array([1.0, 1.7, 2.0, 2.5, 3.0, 3.2])
y_train = np.array([250, 300, 480,  430,   630, 730,])

# %%
plt.plot(x_train,y_train)

# %%
soup_bowl()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 soup_bowl()
#
# NameError: name 'soup_bowl' is not defined
